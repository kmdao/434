# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
import uncertainties as unc
from scipy import stats
from scipy.stats import norm 
from scipy.stats import uniform
from scipy.stats import binom
from scipy.stats import poisson
from scipy.stats import cauchy
import scipy.constants as const
from tabulate import tabulate
import math
from matplotlib import cm
import matplotlib.cm as cm
import seaborn as sns
from scipy.optimize import minimize
from iminuit import Minuit
import pickle
import numpy as np
# %matplotlib inline

# %% [markdown]
# # Task 1

# %%
# open the file of interest, and use pickle loading
infile = open("./higgs_100000_pt_250_500.pkl",'rb') # Higgs Signal
signal = pickle.load(infile)

infile2 = open("./qcd_100000_pt_250_500.pkl",'rb') # QCD Background
background = pickle.load(infile2)

infile3 = open ("./higgs_100000_pt_1000_1200.pkl",'rb') 

infile4 = open("./qcd_100000_pt_1000_1200.pkl",'rb')

# list all keys of the files
print(signal.keys())
print(background.keys())
# Out:
# Index(['pt', 'eta', 'phi', 'mass', 'ee2', 'ee3', 'd2', 'angularity', 't1',
#        't2', 't3', 't21', 't32', 'KtDeltaR'],
#       dtype='object')
# Index(['pt', 'eta', 'phi', 'mass', 'ee2', 'ee3', 'd2', 'angularity', 't1',
#        't2', 't3', 't21', 't32', 'KtDeltaR'],
#       dtype='object')

# %% [markdown]
# # Task 2 Exploration
# We will further explore the LHC data. You will study the correlation between the mass and jet
# substructure variable d2. The goal will be to see if we can build a simple cut based analysis to
# increase the discovery of signal over the background. For this task, we will use the low 𝑝𝑇 files
# (Sample_pt_250_500).

# %% [markdown]
#     a) Make two plots of Mass and d2 each with Signal and Background distributions. Describe the shape of the two distribution, commenting on the discrimination power of signal and back-ground. Also make a 2D scatter plot between Mass and d2 for both signal and background.

# %%
#  Two distributions of Mass and d2
fig, ax = plt.subplots(1,2, figsize=(10,5))

# Histogram of mass signal and background
ax[0].hist(signal['mass'], bins =100, histtype='step', label='signal', color='orange')
ax[0].hist(background['mass'], bins =100, histtype='step', label='background', color='b')
ax[0].set_title('Mass Distribution')
ax[0].set_xlabel('mass[GeV]')
ax[0].set_ylabel('Count')
ax[0].legend()

# Histogram of d2 signal and background
ax[1].hist(signal['d2'], bins =100, histtype='step', label='signal', color='orange')
ax[1].hist(background['d2'], bins =100, histtype='step', label='background', color='b')
ax[1].set_title('d2 Distribution')
ax[1].set_xlabel('d2')
ax[1].set_ylabel('Count')
ax[1].legend()

plt.tight_layout()

# %% [markdown]
#         The signal and background distributions for mass are clearly distinguishable, with the peak of the signal distribution being over 6 times larger than that of the background. Most of the signal distribution count is around this peak at a range of around 110-130 GeV. The background distribution is much more spread out around its peak, with a peak around 90 GeV and most events occuring in the 10-150 GeV range.
#        The signal and background distributions for d2 are less distinguishable and more similar in shape. Both are skewed to the left and have peaks close to a d2 value of 0. The background distribution is slightly more spread out and its peak is lower on the y-axis of events than the signal distribution.

# %%
#  Two scatterplots between Mass and d2 for both signal and background
fig, ax = plt.subplots(1,2, figsize=(10,5))

# Mass vs. d2 for signal
ax[0].grid()
ax[0].scatter(signal['mass'], signal['d2'], s=2, color='orange')
ax[0].set_xlabel('mass[GeV]')
ax[0].set_ylabel('d2')
ax[0].set_title('Signal Scatterplot')

# Mass vs. d2 for background
ax[1].grid()
ax[1].scatter(background['mass'], background['d2'], s=2, color='b')
ax[1].set_xlabel('mass[GeV]')
ax[1].set_ylabel('d2')
ax[1].set_title('Background Scatterplot')

plt.tight_layout()

# %% [markdown]
#     b) Now assume a signal yield of 100 and a background yield of 20,000, re-weight the signal and background distribution such that they satisfy this yield. Then draw two histograms with the signal stacked on the background. Describe the visibility of observing the signal over the background.

# %%
# Set weights for given yield ratio
# For a background yield of 20k, weight is 0.2 and for signal yield of 100 weight is 0.001
# 0.001/0.2 = 100/20k
background_weight = 0.2
signal_weight = 0.001

# %% [markdown]
# #### Mass Reweighting

# %%
# Stacked Histogram with Yields
fig, ax = plt.subplots(figsize=(6,6))
weighted_values_inbin, weighted_bins, _ = ax.hist(background['mass'], bins=150, density=False, label='background', histtype='bar', 
                                                   stacked=True, weights= background_weight * np.ones(background['mass'].shape[0]))


print(f"weighted: For background mass, the yield is {np.sum(weighted_values_inbin)}, the area is {np.sum(weighted_values_inbin) * (weighted_bins[1] - weighted_bins[0]) }")


weighted_values_inbin, weighted_bins, _ = ax.hist(signal['mass'], bins=150, density=False, label='signal', histtype='bar', 
                                                   stacked=True, weights= signal_weight * np.ones(signal['mass'].shape[0]))
print(f"weighted: For signal mass, the yield is {np.sum(weighted_values_inbin)}, the area is {np.sum(weighted_values_inbin) * (weighted_bins[1] - weighted_bins[0]) }")

ax.set_title('Stacked Histogram of Weighted Mass Distribution')
ax.set_xlabel('Mass[GeV]')
ax.set_ylabel('Weighted Count')
ax.legend()
plt.show()
# Out:
# weighted: For background mass, the yield is 19999.999999999814, the area is 41614.023448938126
# weighted: For signal mass, the yield is 99.9999999999962, the area is 88.9789237870973

# %% [markdown]
# The visibility of the signal over background has decreased significantly, with the signal distribution being barely visible when stacked with the background distribution.

# %% [markdown]
# #### d2 Reweighting

# %%
# Stacked Histogram with Yields
fig, ax = plt.subplots(figsize=(8,6))
weighted_values_inbin, weighted_bins, _ = ax.hist(background['d2'], bins=150, range=(0,40), density=False, label='background', histtype='bar', 
                                                   stacked=True, weights= background_weight * np.ones(background['d2'].shape[0]))


print(f"weighted: For background d2, the yield is {np.sum(weighted_values_inbin)}, the area is {np.sum(weighted_values_inbin) * (weighted_bins[1] - weighted_bins[0]) }")


weighted_values_inbin, weighted_bins, _ = ax.hist(signal['d2'], bins=150, range=(0,40), density=False, label='signal', histtype='bar', 
                                                   stacked=True, weights= signal_weight * np.ones(signal['d2'].shape[0]))
print(f"weighted: For signal d2, the yield is {np.sum(weighted_values_inbin)}, the area is {np.sum(weighted_values_inbin) * (weighted_bins[1] - weighted_bins[0]) }")

ax.set_title('Stacked Histogram of Weighted d2 Distribution')
ax.set_xlabel('d2')
ax.set_ylabel('Weighted Count')
ax.legend()

plt.show()
# Out:
# weighted: For background d2, the yield is 19997.1999999998, the area is 5332.586666666613
# weighted: For signal d2, the yield is 99.99999999999643, the area is 26.666666666665716

# %% [markdown]
# Again, the visibility of the signal distribution has decreased and is very small when stacked with the background distribution.

# %% [markdown]
#     c) Using the weighted samples from Q2 apply a Mass cut of [120, 130] GeV. Now again make the two histograms as above. Does the Mass distribution look as you expect it? how does the d2 plot compare to the one in Task 2b

# %%
# apply mass cut
sm_cut = signal.loc[(signal['mass'] >= 120) & (signal['mass'] <= 130)] # Signal cut
bm_cut = background.loc[(background['mass'] >= 120) & (signal['mass'] <= 130)] # Background cut

# %%
# Stacked histograms for mass dist.
fig, ax = plt.subplots(figsize=(8,8))
weighted_values_inbin, weighted_bins, _ = ax.hist(bm_cut['mass'], range=(120,130), bins=150, density=False, label='background', histtype='bar', 
                                                   stacked=True, weights= background_weight * np.ones(bm_cut['mass'].shape[0]))


print(f"weighted: For background mass, the yield is {np.sum(weighted_values_inbin)}, the area is {np.sum(weighted_values_inbin) * (weighted_bins[1] - weighted_bins[0]) }")


weighted_values_inbin, weighted_bins, _ = ax.hist(sm_cut['mass'],range=(120,130), bins=150, density=False, label='signal', histtype='bar', 
                                                   stacked=True, weights= signal_weight * np.ones(sm_cut['mass'].shape[0]))
print(f"weighted: For signal mass, the yield is {np.sum(weighted_values_inbin)}, the area is {np.sum(weighted_values_inbin) * (weighted_bins[1] - weighted_bins[0]) }")

ax.set_title('stacked mass weighted histogram with mass cut')
ax.set_xlabel('Mass[GeV]')
ax.set_ylabel('Weighted Count')
ax.legend()
plt.show()
# Out:
# weighted: For background mass, the yield is 958.4000000000004, the area is 63.89333333332973
# weighted: For signal mass, the yield is 75.8469999999988, the area is 5.056466666666299

# %% [markdown]
# Now, the signal distribution is much more visible. The background distribution is still much larger in area, but the ratio of signal to background distribution area has increased with the mass cut.

# %%
# Stacked hist for d2 dist
fig, ax = plt.subplots(figsize=(8,8))
weighted_values_inbin, weighted_bins, _ = ax.hist(bm_cut['d2'], bins=150, density=False, label='background', histtype='bar', 
                                                   stacked=True, weights= background_weight * np.ones(bm_cut['d2'].shape[0]))


print(f"weighted: For background mass, the yield is {np.sum(weighted_values_inbin)}, the area is {np.sum(weighted_values_inbin) * (weighted_bins[1] - weighted_bins[0]) }")


weighted_values_inbin, weighted_bins, _ = ax.hist(sm_cut['d2'], bins=150, density=False, label='signal', histtype='bar', 
                                                   stacked=True, weights= signal_weight * np.ones(sm_cut['d2'].shape[0]))
print(f"weighted: For signal mass, the yield is {np.sum(weighted_values_inbin)}, the area is {np.sum(weighted_values_inbin) * (weighted_bins[1] - weighted_bins[0]) }")

ax.set_title('stacked d2 weighted histogram with mass cut')
ax.set_xlabel('d2')
ax.set_ylabel('Weighted Count')
ax.legend()
plt.show()
# Out:
# weighted: For background mass, the yield is 4734.2000000000135, the area is 256.92472274257625
# weighted: For signal mass, the yield is 75.8469999999981, the area is 2.1344478108438816

# %% [markdown]
# The signal distribution has become more visible, but it the histogram is still overwhelmingly showing the background distribution. On the horizontal axis in particular, the signal distribution spread is easier to see as the axis' values have been cut to a smaller range.

# %% [markdown]
# # Task 3 Significance Optimization
# Now we want to scan over d2 to find a good cut on d2 to increase our significance. The siginificance
# formula is given below(it’s a good exercise to think about the derivation of the formula), and it is
# in the unit of 𝜎: <br>
# \begin{equation}
# Significance=\frac{N_{signal}}{\sqrt{N_{bkg}}}
# \end{equation}
# We want to reject as many bkg as possible while keep the signal to make signal more visible(siginificant).

# %% [markdown]
# 1. Inspect the d2 distribution after you apply the mass cut, how does it change compared to that without any mass cut? <br>
#   With the mass cut, the d2 signal distribution is more visible in the stacked histogram than before the mass cut.

# %% [markdown]
# 2. Let’s say you choose a d2 cut value of 4, do you want to keep the histogram below 4 of above 4? Which makes signal more siginificant? <br>
# To make signal more significant, the cut in d2 values should be below 4. Looking at the stakced histogram, the signal distribution is most visible in this range.

# %% [markdown]
# 3. What range can be chosen to scan the d2 cut? <br>
# Again, looking at the d2 histogram, the range to scan the d2 cut is where the signal distribution is most visible. This is around [0,4].

# %% [markdown]
# After you have some ideas, choose a range to scan d2. For each d2 value you can calculate a significane. Then plot significance vs. d2 cut value, choose the cut value corresponding to 3𝜎. Now plot the Mass distributions with the mass cut and with the d2 cut. What do you observe in this plot? What is the significance value with these two cuts(mass and t2)? A good checking is that compare the significance before any d2 cut and with a very large d2 cut.

# %%
# scanning d2 in rnage [0,4] for 100 sig vals

significances = np.zeros(100) # Set up empty vector for significances
vals = np.linspace(0,4,100) # values in cut range 

# USing formula above, Loop to calculate significances according to cut and throw out backgrounds
for i in range(100):
    # Scan d2 from 0 to 4
    sd2_cut = signal.loc[signal['d2'] <= vals[i]] # Signal cut
    bd2_cut = background.loc[(background['d2'] <= vals[i])] # Background cut 
    N_sig = signal_weight * len(sd2_cut) # numerator N_sig
    N_bkg = background_weight * len(bd2_cut) # Den N_bkg
    if N_bkg==0:
        significances[i] = 0
    else:
        significances[i] = N_sig / np.sqrt(N_bkg) # significance formula

# Plot significance vs. d2 cut value
plt.scatter(vals, significances)
plt.title('Significance vs. d2 Cut Value')
plt.xlabel('d2 Cut Value')
plt.ylabel('Significance')
# Out:
# Text(0, 0.5, 'Significance')

# %%
# Choose cut value using 3 sigma
vals = np.linspace(0,4,100)
threesig = 3 * np.std(significances)
cutval = 0

for j in range(100):
    if significances[99 - j] >= threesig:
        cutval = vals[99-j]
        break
# Cut
sm2 = sm_cut[sm_cut['d2'] <= cutval] # signal d2 and mass cut applied
bm2 = bm_cut[bm_cut['d2'] <= cutval] # background d2 and mass cut applied 


# Plot mass distributions with mass and d2 cuts


fig, ax = plt.subplots(figsize=(8,8))
weighted_values_inbin, weighted_bins, _ = ax.hist(bm2['mass'], range=(120,130), bins=150, density=False, label='background', histtype='bar', 
                                                   stacked=True, weights= background_weight * np.ones(bm2['mass'].shape[0]))



weighted_values_inbin, weighted_bins, _ = ax.hist(sm2['mass'],range=(120,130), bins=150, density=False, label='signal', histtype='bar', 
                                                   stacked=True, weights= signal_weight * np.ones(sm2['mass'].shape[0]))


ax.set_title('stacked mass weighted histogram with mass and d2 cut')
ax.set_xlabel('Mass[GeV]')
ax.set_ylabel('Weighted Count')
ax.legend()
plt.show()

# %% [markdown]
# Now we can see much more of the signal distribution in the stacked historgram. While there is still a good amount of background, the shape of the signal mass distribution is now clear.

# %% [markdown]
# # Bonus
# Optimize discovery significance for high Pt data (Sample_pt_1000_1200) and explore combination
# of at least 3 features.
